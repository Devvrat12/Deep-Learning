# %% [markdown]
# <a href="https://colab.research.google.com/github/Devvrat12/Deep-Learning/blob/main/Deep_Learning_class_prac.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %%
from keras.models import Sequential
from keras.layers import Input, Dense

# %%
x = np.array([[0,0],
              [0,1],
              [1,0],
              [1,1]])

y = np.array([[0],
              [1],
              [1],
              [1]])

# %%
tf.keras.utils.set_random_seed(42)

# %%
model = Sequential()

model.add(Input(shape=(2,)))
model.add(Dense(1, activation='relu'))

# %%
model.compile(
    optimizer='sgd',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
model.fit(x, y, epochs=100)

print(model.predict(x))

loss, accuracy = model.evaluate(x, y, verbose=0)

print("Accuracy:", accuracy)
print("Accuracy %:", accuracy * 100)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 744ms/step - accuracy: 0.7500 - loss: 0.1941
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.7500 - loss: 0.1897
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.7500 - loss: 0.1861
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.7500 - loss: 0.1827
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7500 - loss: 0.1794
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.1762
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.1732
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.1703
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.1674
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.1647
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.1620
# Epoch 12/100
# ...

# %%
x = np.array([[0,0],
              [0,1],
              [1,0],
              [1,1]])

y = np.array([[0],
              [0],
              [0],
              [1]])

tf.keras.utils.set_random_seed(42)

model = Sequential()

model.add(Input(shape=(2,)))
model.add(Dense(1, activation='relu'))

model.compile(
    optimizer='sgd',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.fit(x, y, epochs=100)

print(model.predict(x))

loss, accuracy = model.evaluate(x, y, verbose=0)

print("Accuracy:", accuracy)
print("Accuracy %:", accuracy * 100)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 722ms/step - accuracy: 0.7500 - loss: 4.1396
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7500 - loss: 4.1354
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7500 - loss: 4.1313
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7500 - loss: 2.0197
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7500 - loss: 4.0295
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7500 - loss: 4.0295
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7500 - loss: 4.0295
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7500 - loss: 4.0295
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7500 - loss: 4.0295
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7500 - loss: 4.0295
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7500 - loss: 4.0295
# Epoch 12/100
# ...

# %%
x = np.array([[0,0],
              [0,1],
              [1,0],
              [1,1]])

y = np.array([[0],
              [0],
              [0],
              [1]])

tf.keras.utils.set_random_seed(42)

model = Sequential()

model.add(Input(shape=(2,)))
model.add(Dense(1, activation='relu'))

model.compile(
    optimizer='sgd',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.fit(x, y, epochs=500)

print(model.predict(x))

loss, accuracy = model.evaluate(x, y, verbose=0)

print("Accuracy:", accuracy)
print("Accuracy %:", accuracy * 100)
# Out:
# Epoch 1/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.7500 - loss: 4.1396
# Epoch 2/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.7500 - loss: 4.1354
# Epoch 3/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7500 - loss: 4.1313
# Epoch 4/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7500 - loss: 2.0197
# Epoch 5/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7500 - loss: 4.0295
# Epoch 6/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7500 - loss: 4.0295
# Epoch 7/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.7500 - loss: 4.0295
# Epoch 8/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7500 - loss: 4.0295
# Epoch 9/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7500 - loss: 4.0295
# Epoch 10/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.7500 - loss: 4.0295
# Epoch 11/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7500 - loss: 4.0295
# Epoch 12/500
# ...

# %%
x = np.array([[0,0],
              [0,1],
              [1,0],
              [1,1]])

y = np.array([[0],
              [0],
              [0],
              [1]])

tf.keras.utils.set_random_seed(42)

model = Sequential()

model.add(Input(shape=(2,)))
model.add(Dense(1, activation='sigmoid'))

model.compile(
    optimizer='sgd',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

h = model.fit(x, y, epochs=100, verbose= 0)

print(model.predict(x))

loss, accuracy = model.evaluate(x, y, verbose=0)

print("Accuracy:", accuracy)
print("Accuracy %:", accuracy * 100)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7ba43835b920> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# [[0.410036  ]
#  [0.5040191 ]
#  [0.6313163 ]
#  [0.71458566]]
# Accuracy: 0.5
# Accuracy %: 50.0

# %%
h.history
# Out:
# {'accuracy': [0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5],
#  'loss': [0.7929359078407288,
#   0.7909154891967773,
#   0.7889065146446228,
# ...

# %%
x = np.array([[0,0],
              [0,1],
              [1,0],
              [1,1]])

y = np.array([[0],
              [0],
              [0],
              [1]])

tf.keras.utils.set_random_seed(42)

model = Sequential()

model.add(Input(shape=(2,)))
model.add(Dense(1, activation='sigmoid'))

model.compile(
    optimizer='sgd',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

p = model.fit(x, y, epochs=500, verbose= 0)

print(model.predict(x))

loss, accuracy = model.evaluate(x, y, verbose=0)

print("Accuracy:", accuracy)
print("Accuracy %:", accuracy * 100)
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7ba4382ada80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# [[0.2403903 ]
#  [0.32122114]
#  [0.41610104]
#  [0.51588845]]
# Accuracy: 1.0
# Accuracy %: 100.0

# %%
p.history
# Out:
# {'accuracy': [0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.5,
#   0.75,
#   0.75,
#   0.75,
#   0.75,
# ...
